# %% [markdown]
# This notebook is to check the performance of 9 layer CNN + Maxpooling network on the accuracy of scenery classification.

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.metrics import classification_report

# %%
image_path = "../input/intel-image-classification/seg_train/seg_train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="training",
  seed=123)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="validation",
  seed=123)

test_path = "../input/intel-image-classification/seg_test/seg_test"
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
  image_size=(224,224),
  batch_size=32)

new_test_path = "../input/new-test-dataset/test_images"
new_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  new_test_path,
  image_size=(224,224),
  batch_size=32)
# Out:
# Found 14034 files belonging to 6 classes.
# Using 10526 files for training.
# Found 14034 files belonging to 6 classes.
# Using 3508 files for validation.
# Found 3000 files belonging to 6 classes.
# Found 37 files belonging to 6 classes.

# %%
import glob
import pathlib 

data_dir = pathlib.Path(image_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %%
## visualize train set images
image_batch, label_batch = next(iter(train_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize validation images 
image_batch, label_batch = next(iter(val_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize test images 
image_batch, label_batch = next(iter(test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize new test images 
image_batch, label_batch = next(iter(new_test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.resize(img , (224,224))
        if img is not None:
            images.append(img)
    return images

pred_images = load_images_from_folder("../input/intel-image-classification/seg_pred/seg_pred")

# %%
type(pred_images)
# Out:
# list

# %%
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 224, 224, 3)

# %%
## visualize prediction images 
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(pred_images[i])
    plt.axis("off")

# %%
## 9 layer cnn + max pooling + batchnormalization

model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D( activation='relu', input_shape=(224, 224, 3),padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.BatchNormalization(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation=tf.nn.relu),
tf.keras.layers.Dense(6, activation=tf.nn.softmax)])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'], )
# %time history = model.fit(train_ds, epochs=15, validation_data = val_ds)
##
test_loss, test_acc = model.evaluate(test_ds)
print("Test image accuracy :{}".format(test_acc))
##
test_loss_new, test_acc_new = model.evaluate(new_test_ds)
print("Test image accuracy for new data set :{}".format(test_acc_new))
##
plt.plot(history.history['accuracy'], '-o' ,label='accuracy')
plt.plot(history.history['val_accuracy'], '-o', label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
##
model.save('model_cnn_9')
##

## for validation data set , check the classification report.
val_pred = np.array([])
val_labels = np.array([])
for x, y in test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    val_pred = np.concatenate([val_pred,np.array(predictions)])
    val_labels = np.concatenate([val_labels , y.numpy()])
    
##
print('Classification Report')
target_names = class_names
print(classification_report(val_labels, val_pred, target_names=class_names))
##
print(model.summary())
##
pred_images_prediction = model.predict(pred_images)
##
pred_images_class = []
for i in range(len(pred_images_prediction)):
    pred_images_class.append(np.argmax(pred_images_prediction[i], axis = -1))
##
## visualize prediction images with the prediction 
plt.figure(figsize=(10, 10))
for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(pred_images[i])
    plt.title(class_names[pred_images_class[i]])
    plt.axis("off")
# Out:
# Epoch 1/15
# 329/329 [==============================] - 1058s 3s/step - loss: 1.4356 - accuracy: 0.4513 - val_loss: 1.5719 - val_accuracy: 0.5077
# Epoch 2/15
# 329/329 [==============================] - 946s 3s/step - loss: 1.0209 - accuracy: 0.5938 - val_loss: 0.8739 - val_accuracy: 0.6388
# Epoch 3/15
# 329/329 [==============================] - 945s 3s/step - loss: 0.7972 - accuracy: 0.6751 - val_loss: 1.6698 - val_accuracy: 0.5060
# Epoch 4/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.7255 - accuracy: 0.7116 - val_loss: 0.8066 - val_accuracy: 0.6690
# Epoch 5/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.6545 - accuracy: 0.7495 - val_loss: 0.6063 - val_accuracy: 0.7737
# Epoch 6/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.5777 - accuracy: 0.7818 - val_loss: 0.6225 - val_accuracy: 0.7722
# Epoch 7/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.5404 - accuracy: 0.7982 - val_loss: 0.6069 - val_accuracy: 0.7848
# Epoch 8/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.5011 - accuracy: 0.8167 - val_loss: 0.8491 - val_accuracy: 0.7038
# Epoch 9/15
# 329/329 [==============================] - 945s 3s/step - loss: 0.4816 - accuracy: 0.8248 - val_loss: 0.4917 - val_accuracy: 0.8210
# Epoch 10/15
# 329/329 [==============================] - 945s 3s/step - loss: 0.4148 - accuracy: 0.8467 - val_loss: 0.5254 - val_accuracy: 0.8158
# Epoch 12/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.3930 - accuracy: 0.8559 - val_loss: 0.5305 - val_accuracy: 0.8235
# Epoch 13/15
# 329/329 [==============================] - 945s 3s/step - loss: 0.3232 - accuracy: 0.8823 - val_loss: 0.5704 - val_accuracy: 0.8027
# Epoch 15/15
# 329/329 [==============================] - 946s 3s/step - loss: 0.3017 - accuracy: 0.8887 - val_loss: 0.4900 - val_accuracy: 0.8367
# CPU times: user 30min 19s, sys: 9min 53s, total: 40min 13s
# Wall time: 3h 58min 17s
# 94/94 [==============================] - 219s 2s/step - loss: 0.5638 - accuracy: 0.8297
# Test image accuracy :0.8296666741371155
# 2/2 [==============================] - 5s 3s/step - loss: 2.5868 - accuracy: 0.5676
# Test image accuracy for new data set :0.5675675868988037
# Classification Report
#               precision    recall  f1-score   support
#
#    buildings       0.82      0.86      0.84       437
#       forest       0.97      0.95      0.96       474
#      glacier       0.73      0.84      0.78       553
#     mountain       0.75      0.77      0.76       525
#          sea       0.88      0.74      0.80       510
#       street       0.88      0.85      0.87       501
#
#     accuracy                           0.83      3000
#    macro avg       0.84      0.83      0.83      3000
# weighted avg       0.84      0.83      0.83      3000
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               589952
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 7,637,958
# Trainable params: 7,636,934
# Non-trainable params: 1,024
# _________________________________________________________________
# None

# %% [markdown]
# Model with 9 layers of CNN has not performed better than 7 layer CNN + Max Pooling which gave an accuracy of 0.87.

# %%
## for new test  data set , check the classification report.
new_val_pred = np.array([])
new_val_labels = np.array([])
for x, y in new_test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    new_val_pred = np.concatenate([new_val_pred,np.array(predictions)])
    new_val_labels = np.concatenate([new_val_labels , y.numpy()])
    
##
print('Classification Report')
target_names = class_names
print(classification_report(new_val_labels, new_val_pred, target_names=class_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#    buildings       0.86      1.00      0.92         6
#       forest       1.00      0.80      0.89         5
#      glacier       0.86      1.00      0.92         6
#     mountain       0.83      0.83      0.83         6
#          sea       1.00      1.00      1.00         7
#       street       1.00      0.86      0.92         7
#
#     accuracy                           0.92        37
#    macro avg       0.92      0.92      0.92        37
# weighted avg       0.93      0.92      0.92        37

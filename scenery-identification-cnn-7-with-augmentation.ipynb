# %% [markdown]
# This analysis is to check if the 7 layer CNN + Max Pooling layer will perform better with data augmentation such as RandomFlip, RandomRotation and RandomZoom.

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.metrics import classification_report

# %%
image_path = "../input/intel-image-classification/seg_train/seg_train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="training",
  seed=123)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="validation",
  seed=123)

test_path = "../input/intel-image-classification/seg_test/seg_test"
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
  image_size=(224,224),
  batch_size=32)

new_test_path = "../input/new-test-dataset/test_images"
new_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  new_test_path,
  image_size=(224,224),
  batch_size=32)
# Out:
# Found 14034 files belonging to 6 classes.
# Using 10526 files for training.
# Found 14034 files belonging to 6 classes.
# Using 3508 files for validation.
# Found 3000 files belonging to 6 classes.
# Found 37 files belonging to 6 classes.

# %%
import glob
import pathlib 

data_dir = pathlib.Path(image_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %%
## visualize train set images
image_batch, label_batch = next(iter(train_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize validation images 
image_batch, label_batch = next(iter(val_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize test images 
image_batch, label_batch = next(iter(test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize new test images 
image_batch, label_batch = next(iter(new_test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.resize(img , (224,224))
        if img is not None:
            images.append(img)
    return images

pred_images = load_images_from_folder("../input/intel-image-classification/seg_pred/seg_pred")

# %%
type(pred_images)
# Out:
# list

# %%
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 224, 224, 3)

# %%
## visualize prediction images 
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(pred_images[i])
    plt.axis("off")

# %% [markdown]
# Increase epoch to 50 and add data augmentation layer.

# %%
## 7 layer cnn + max pooling + batchnormalization + augmentation

model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1),
    tf.keras.layers.Conv2D( activation='relu', input_shape=(224, 224, 3),padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.BatchNormalization(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation=tf.nn.relu),
tf.keras.layers.Dense(6, activation=tf.nn.softmax)])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'], )
# %time history = model.fit(train_ds, epochs=50, validation_data = val_ds)
##
test_loss, test_acc = model.evaluate(test_ds)
print("Test image accuracy :{}".format(test_acc))
##
new_test_loss, new_test_acc = model.evaluate(new_test_ds)
print("Test image accuracy :{}".format(new_test_acc))
##
plt.plot(history.history['accuracy'], '-o' ,label='accuracy')
plt.plot(history.history['val_accuracy'], '-o', label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
##
model.save('model_cnn_7')
##

## for test data set , check the classification report.
val_pred = np.array([])
val_labels = np.array([])
for x, y in test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    val_pred = np.concatenate([val_pred,np.array(predictions)])
    val_labels = np.concatenate([val_labels , y.numpy()])
    
##
print('Classification Report for test ds')
target_names = class_names
print(classification_report(val_labels, val_pred, target_names=class_names))
##
## for new test data set , check the classification report.
new_val_pred = np.array([])
new_val_labels = np.array([])
for x, y in new_test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    new_val_pred = np.concatenate([new_val_pred,np.array(predictions)])
    new_val_labels = np.concatenate([new_val_labels , y.numpy()])
    
##
print('Classification Report for new test ds')
target_names = class_names
print(classification_report(new_val_labels, new_val_pred, target_names=class_names))
##
print(model.summary())
##
pred_images_prediction = model.predict(pred_images)
##
pred_images_class = []
for i in range(len(pred_images_prediction)):
    pred_images_class.append(np.argmax(pred_images_prediction[i], axis = -1))
##
## visualize prediction images with the prediction 
plt.figure(figsize=(10, 10))
for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(pred_images[i])
    plt.title(class_names[pred_images_class[i]])
    plt.axis("off")
# Out:
# Epoch 1/50
# 329/329 [==============================] - 240s 708ms/step - loss: 1.4597 - accuracy: 0.4377 - val_loss: 1.7072 - val_accuracy: 0.4561
# Epoch 2/50
# 329/329 [==============================] - 171s 520ms/step - loss: 1.1224 - accuracy: 0.5578 - val_loss: 1.4739 - val_accuracy: 0.4441
# Epoch 3/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.9831 - accuracy: 0.6080 - val_loss: 0.9782 - val_accuracy: 0.6263
# Epoch 4/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.9530 - accuracy: 0.6292 - val_loss: 1.4061 - val_accuracy: 0.5083
# Epoch 5/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.9550 - accuracy: 0.6260 - val_loss: 0.8261 - val_accuracy: 0.6747
# Epoch 6/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.8604 - accuracy: 0.6689 - val_loss: 0.9515 - val_accuracy: 0.6442
# Epoch 7/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.9125 - accuracy: 0.6389 - val_loss: 0.7475 - val_accuracy: 0.7115
# Epoch 8/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.8272 - accuracy: 0.6830 - val_loss: 3.1939 - val_accuracy: 0.1993
# Epoch 9/50
# 329/329 [==============================] - 171s 519ms/step - loss: 1.4056 - accuracy: 0.4308 - val_loss: 1.0653 - val_accuracy: 0.6089
# Epoch 10/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.9225 - accuracy: 0.6469 - val_loss: 0.8012 - val_accuracy: 0.6873
# Epoch 11/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.8599 - accuracy: 0.6654 - val_loss: 0.7213 - val_accuracy: 0.7309
# Epoch 12/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.7547 - accuracy: 0.7151 - val_loss: 0.6935 - val_accuracy: 0.7489
# Epoch 14/50
# 329/329 [==============================] - 171s 518ms/step - loss: 0.7170 - accuracy: 0.7294 - val_loss: 0.6255 - val_accuracy: 0.7748
# Epoch 15/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.6816 - accuracy: 0.7430 - val_loss: 0.6993 - val_accuracy: 0.7614
# Epoch 16/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.6554 - accuracy: 0.7600 - val_loss: 0.5587 - val_accuracy: 0.7973
# Epoch 17/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.6323 - accuracy: 0.7660 - val_loss: 0.5164 - val_accuracy: 0.8147
# Epoch 18/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.6011 - accuracy: 0.7791 - val_loss: 0.5404 - val_accuracy: 0.7962
# Epoch 19/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5867 - accuracy: 0.7872 - val_loss: 0.7115 - val_accuracy: 0.7238
# Epoch 20/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.6155 - accuracy: 0.7689 - val_loss: 0.5931 - val_accuracy: 0.7893
# Epoch 21/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5615 - accuracy: 0.7917 - val_loss: 0.4535 - val_accuracy: 0.8401
# Epoch 22/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.5364 - accuracy: 0.8076 - val_loss: 0.5233 - val_accuracy: 0.8241
# Epoch 23/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.5521 - accuracy: 0.7959 - val_loss: 0.9282 - val_accuracy: 0.6702
# Epoch 24/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5182 - accuracy: 0.8161 - val_loss: 0.5367 - val_accuracy: 0.8101
# Epoch 25/50
# 329/329 [==============================] - 172s 520ms/step - loss: 0.4787 - accuracy: 0.8211 - val_loss: 0.5225 - val_accuracy: 0.8170
# Epoch 26/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5006 - accuracy: 0.8183 - val_loss: 0.6299 - val_accuracy: 0.8030
# Epoch 28/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.4899 - accuracy: 0.8227 - val_loss: 0.4377 - val_accuracy: 0.8398
# Epoch 29/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.4569 - accuracy: 0.8355 - val_loss: 0.5332 - val_accuracy: 0.8107
# Epoch 30/50
# 329/329 [==============================] - 172s 521ms/step - loss: 0.5013 - accuracy: 0.8164 - val_loss: 0.5668 - val_accuracy: 0.7848
# Epoch 31/50
# 329/329 [==============================] - 171s 521ms/step - loss: 0.5178 - accuracy: 0.8129 - val_loss: 0.4829 - val_accuracy: 0.8384
# Epoch 32/50
# 329/329 [==============================] - 172s 521ms/step - loss: 0.4458 - accuracy: 0.8400 - val_loss: 0.5829 - val_accuracy: 0.8372
# Epoch 33/50
# 329/329 [==============================] - 171s 521ms/step - loss: 0.4308 - accuracy: 0.8424 - val_loss: 0.4325 - val_accuracy: 0.8469
# Epoch 34/50
# 329/329 [==============================] - 171s 521ms/step - loss: 0.4057 - accuracy: 0.8506 - val_loss: 0.4733 - val_accuracy: 0.8278
# Epoch 35/50
# 329/329 [==============================] - 172s 521ms/step - loss: 0.3947 - accuracy: 0.8598 - val_loss: 0.4163 - val_accuracy: 0.8578
# Epoch 36/50
# 329/329 [==============================] - 172s 522ms/step - loss: 0.4140 - accuracy: 0.8505 - val_loss: 2.2322 - val_accuracy: 0.5282
# Epoch 37/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.7906 - accuracy: 0.6947 - val_loss: 0.8991 - val_accuracy: 0.6830
# Epoch 38/50
# 329/329 [==============================] - 172s 521ms/step - loss: 0.7177 - accuracy: 0.7274 - val_loss: 0.5825 - val_accuracy: 0.7948
# Epoch 39/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.7818 - accuracy: 0.7003 - val_loss: 0.9143 - val_accuracy: 0.6699
# Epoch 40/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.6744 - accuracy: 0.7524 - val_loss: 0.6362 - val_accuracy: 0.7580
# Epoch 41/50
# 329/329 [==============================] - 171s 521ms/step - loss: 0.5620 - accuracy: 0.7961 - val_loss: 0.5796 - val_accuracy: 0.7968
# Epoch 42/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5205 - accuracy: 0.8109 - val_loss: 0.4775 - val_accuracy: 0.8264
# Epoch 43/50
# 329/329 [==============================] - 171s 520ms/step - loss: 1.0048 - accuracy: 0.6039 - val_loss: 1.1924 - val_accuracy: 0.7278
# Epoch 44/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.6969 - accuracy: 0.7388 - val_loss: 1.5643 - val_accuracy: 0.7648
# Epoch 45/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5329 - accuracy: 0.8050 - val_loss: 0.6918 - val_accuracy: 0.8421
# Epoch 46/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.4600 - accuracy: 0.8339 - val_loss: 0.4436 - val_accuracy: 0.8392
# Epoch 47/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.4694 - accuracy: 0.8325 - val_loss: 0.5944 - val_accuracy: 0.8033
# Epoch 49/50
# 329/329 [==============================] - 171s 519ms/step - loss: 0.3981 - accuracy: 0.8581 - val_loss: 0.3993 - val_accuracy: 0.8657
# Epoch 50/50
# 329/329 [==============================] - 171s 520ms/step - loss: 0.4094 - accuracy: 0.8508 - val_loss: 0.4958 - val_accuracy: 0.8529
# CPU times: user 31min 34s, sys: 6min 51s, total: 38min 26s
# Wall time: 2h 23min 47s
# 94/94 [==============================] - 52s 545ms/step - loss: 1.0048 - accuracy: 0.8433
# Test image accuracy :0.8433333039283752
# 2/2 [==============================] - 1s 457ms/step - loss: 1.3097 - accuracy: 0.6486
# Test image accuracy :0.6486486196517944
# Classification Report for test ds
#               precision    recall  f1-score   support
#
#    buildings       0.92      0.78      0.84       437
#       forest       0.95      0.98      0.96       474
#      glacier       0.87      0.69      0.76       553
#     mountain       0.76      0.80      0.78       525
#          sea       0.74      0.92      0.82       510
#       street       0.87      0.90      0.89       501
#
#     accuracy                           0.84      3000
#    macro avg       0.85      0.84      0.84      3000
# weighted avg       0.85      0.84      0.84      3000
#
# Classification Report for new test ds
#               precision    recall  f1-score   support
#
#    buildings       0.83      0.83      0.83         6
#       forest       1.00      1.00      1.00         5
#      glacier       0.86      1.00      0.92         6
#     mountain       0.80      0.67      0.73         6
#          sea       1.00      1.00      1.00         7
#       street       1.00      1.00      1.00         7
#
#     accuracy                           0.92        37
#    macro avg       0.92      0.92      0.91        37
# weighted avg       0.92      0.92      0.92        37
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# random_flip (RandomFlip)     (None, 224, 224, 3)       0
# _________________________________________________________________
# random_rotation (RandomRotat (None, 224, 224, 3)       0
# _________________________________________________________________
# random_zoom (RandomZoom)     (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 512)       1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 6,376,006
# Trainable params: 6,374,982
# Non-trainable params: 1,024
# _________________________________________________________________
# None

# %% [markdown]
# With data augmentation , the train accuracy reachs to a mx 0.85 and followed in close by validation accuracy.
# How ever the test set accuracy does not improve further than 0.85.

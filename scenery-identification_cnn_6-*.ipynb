# %% [markdown]
# In this notebook, scenery classification is done with 6 layers of CNN + MaxPooling. Parameters such as learning rate and epochs are varied to test the model accuracy on test data.

# %% [markdown]
# Data source : https://www.kaggle.com/puneet6060/intel-image-classification

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.metrics import classification_report

# %%
image_path = "../input/intel-image-classification/seg_train/seg_train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="training",
  seed=123)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="validation",
  seed=123)

test_path = "../input/intel-image-classification/seg_test/seg_test"
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
  image_size=(224,224),
  batch_size=32)
# Out:
# Found 14034 files belonging to 6 classes.
# Using 10526 files for training.
# Found 14034 files belonging to 6 classes.
# Using 3508 files for validation.
# Found 3000 files belonging to 6 classes.

# %%
import glob
import pathlib 

data_dir = pathlib.Path(image_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %%
## visualize train set images
image_batch, label_batch = next(iter(train_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize validation images 
image_batch, label_batch = next(iter(val_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize test images 
image_batch, label_batch = next(iter(test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.resize(img , (224,224))
        if img is not None:
            images.append(img)
    return images

pred_images = load_images_from_folder("../input/intel-image-classification/seg_pred/seg_pred")

# %%
type(pred_images)
# Out:
# list

# %%
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 224, 224, 3)

# %%
## visualize prediction images 
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(pred_images[i])
    plt.axis("off")

# %%
## 6 layer cnn + max pooling + batchnormalization

model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D( activation='relu', input_shape=(224, 224, 3),padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation=tf.nn.relu),
tf.keras.layers.Dense(6, activation=tf.nn.softmax)])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'], )
# %time history = model.fit(train_ds, epochs=15, validation_data = val_ds)
##
test_loss, test_acc = model.evaluate(test_ds)
print("Test image accuracy :{}".format(test_acc))
##
plt.plot(history.history['accuracy'], '-o' ,label='accuracy')
plt.plot(history.history['val_accuracy'], '-o', label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
##
model.save('model_cnn5')
##

## for validation data set , check the classification report.
val_pred = np.array([])
val_labels = np.array([])
for x, y in test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    val_pred = np.concatenate([val_pred,np.array(predictions)])
    val_labels = np.concatenate([val_labels , y.numpy()])
    
##
print('Classification Report')
target_names = class_names
print(classification_report(val_labels, val_pred, target_names=class_names))
##
print(model.summary())
##
pred_images_prediction = model.predict(pred_images)
##
pred_images_class = []
for i in range(len(pred_images_prediction)):
    pred_images_class.append(np.argmax(pred_images_prediction[i], axis = -1))
##
## visualize prediction images with the prediction 
plt.figure(figsize=(10, 10))
for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(pred_images[i])
    plt.title(class_names[pred_images_class[i]])
    plt.axis("off")
# Out:
# Epoch 1/15
# 329/329 [==============================] - 239s 704ms/step - loss: 1.4049 - accuracy: 0.4656 - val_loss: 1.7022 - val_accuracy: 0.3757
# Epoch 2/15
# 329/329 [==============================] - 168s 510ms/step - loss: 0.9018 - accuracy: 0.6581 - val_loss: 1.4432 - val_accuracy: 0.5202
# Epoch 3/15
# 329/329 [==============================] - 168s 509ms/step - loss: 0.6975 - accuracy: 0.7335 - val_loss: 2.2897 - val_accuracy: 0.4857
# Epoch 4/15
# 329/329 [==============================] - 168s 510ms/step - loss: 0.6430 - accuracy: 0.7652 - val_loss: 0.7403 - val_accuracy: 0.7138
# Epoch 5/15
# 329/329 [==============================] - 168s 510ms/step - loss: 0.5514 - accuracy: 0.8006 - val_loss: 0.5610 - val_accuracy: 0.8010
# Epoch 6/15
# 329/329 [==============================] - 168s 511ms/step - loss: 0.5108 - accuracy: 0.8077 - val_loss: 0.5607 - val_accuracy: 0.7816
# Epoch 7/15
# 329/329 [==============================] - 168s 510ms/step - loss: 0.4571 - accuracy: 0.8389 - val_loss: 0.5643 - val_accuracy: 0.7987
# Epoch 8/15
# 329/329 [==============================] - 168s 511ms/step - loss: 0.4275 - accuracy: 0.8466 - val_loss: 0.5216 - val_accuracy: 0.8042
# Epoch 9/15
# 329/329 [==============================] - 168s 511ms/step - loss: 0.4020 - accuracy: 0.8567 - val_loss: 0.4597 - val_accuracy: 0.8347
# Epoch 10/15
# 329/329 [==============================] - 168s 509ms/step - loss: 0.3536 - accuracy: 0.8764 - val_loss: 0.8565 - val_accuracy: 0.7306
# Epoch 11/15
# 329/329 [==============================] - 168s 509ms/step - loss: 0.3429 - accuracy: 0.8786 - val_loss: 0.4609 - val_accuracy: 0.8347
# Epoch 12/15
# 329/329 [==============================] - 167s 509ms/step - loss: 0.3379 - accuracy: 0.8777 - val_loss: 0.4598 - val_accuracy: 0.8415
# Epoch 13/15
# 329/329 [==============================] - 168s 509ms/step - loss: 0.3216 - accuracy: 0.8869 - val_loss: 0.4400 - val_accuracy: 0.8540
# Epoch 14/15
# 329/329 [==============================] - 168s 510ms/step - loss: 0.2972 - accuracy: 0.8944 - val_loss: 0.4501 - val_accuracy: 0.8652
# Epoch 15/15
# 329/329 [==============================] - 168s 509ms/step - loss: 0.2601 - accuracy: 0.9087 - val_loss: 0.5843 - val_accuracy: 0.8042
# CPU times: user 9min 23s, sys: 1min 50s, total: 11min 14s
# Wall time: 43min 9s
# 94/94 [==============================] - 47s 501ms/step - loss: 0.6049 - accuracy: 0.8057
# Test image accuracy :0.8056666851043701
# Classification Report
#               precision    recall  f1-score   support
#
#    buildings       0.94      0.58      0.72       437
#       forest       0.85      0.98      0.91       474
#      glacier       0.74      0.82      0.78       553
#     mountain       0.78      0.70      0.74       525
#          sea       0.75      0.87      0.80       510
#       street       0.84      0.86      0.85       501
#
#     accuracy                           0.80      3000
#    macro avg       0.82      0.80      0.80      3000
# weighted avg       0.81      0.80      0.80      3000
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 512)       1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               589952
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 4,540,998
# Trainable params: 4,539,718
# Non-trainable params: 1,280
# _________________________________________________________________
# None

# %%
## 6 layer cnn + max pooling + batchnormalization + 25 epochs

model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D( activation='relu', input_shape=(224, 224, 3),padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation=tf.nn.relu),
tf.keras.layers.Dense(6, activation=tf.nn.softmax)])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'], )
# %time history = model.fit(train_ds, epochs=25, validation_data = val_ds)
##
test_loss, test_acc = model.evaluate(test_ds)
print("Test image accuracy :{}".format(test_acc))
##
plt.plot(history.history['accuracy'], '-o' ,label='accuracy')
plt.plot(history.history['val_accuracy'], '-o', label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
##
model.save('model_cnn6')
##

## for validation data set , check the classification report.
val_pred = np.array([])
val_labels = np.array([])
for x, y in test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    val_pred = np.concatenate([val_pred,np.array(predictions)])
    val_labels = np.concatenate([val_labels , y.numpy()])
    
##
print('Classification Report')
target_names = class_names
print(classification_report(val_labels, val_pred, target_names=class_names))
##
print(model.summary())
##
pred_images_prediction = model.predict(pred_images)
##
pred_images_class = []
for i in range(len(pred_images_prediction)):
    pred_images_class.append(np.argmax(pred_images_prediction[i], axis = -1))
##
## visualize prediction images with the prediction 
plt.figure(figsize=(10, 10))
for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(pred_images[i])
    plt.title(class_names[pred_images_class[i]])
    plt.axis("off")
# Out:
# Epoch 1/25
# 329/329 [==============================] - 181s 546ms/step - loss: 1.4776 - accuracy: 0.4388 - val_loss: 1.3840 - val_accuracy: 0.4809
# Epoch 2/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.9511 - accuracy: 0.6320 - val_loss: 1.0106 - val_accuracy: 0.5738
# Epoch 3/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.8018 - accuracy: 0.6796 - val_loss: 1.1200 - val_accuracy: 0.5770
# Epoch 4/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.7112 - accuracy: 0.7291 - val_loss: 0.7387 - val_accuracy: 0.7152
# Epoch 5/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.6489 - accuracy: 0.7607 - val_loss: 0.9924 - val_accuracy: 0.6391
# Epoch 6/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.5854 - accuracy: 0.7814 - val_loss: 0.6182 - val_accuracy: 0.7688
# Epoch 7/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.5303 - accuracy: 0.8112 - val_loss: 0.6833 - val_accuracy: 0.7235
# Epoch 8/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.5035 - accuracy: 0.8175 - val_loss: 0.5005 - val_accuracy: 0.8196
# Epoch 9/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.4524 - accuracy: 0.8379 - val_loss: 0.6485 - val_accuracy: 0.7440
# Epoch 10/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.4350 - accuracy: 0.8414 - val_loss: 0.6041 - val_accuracy: 0.7811
# Epoch 11/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.4062 - accuracy: 0.8490 - val_loss: 0.4925 - val_accuracy: 0.8224
# Epoch 12/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.3822 - accuracy: 0.8624 - val_loss: 0.5184 - val_accuracy: 0.8335
# Epoch 13/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.3539 - accuracy: 0.8709 - val_loss: 0.4539 - val_accuracy: 0.8472
# Epoch 14/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.3199 - accuracy: 0.8844 - val_loss: 0.4620 - val_accuracy: 0.8458
# Epoch 15/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.3326 - accuracy: 0.8783 - val_loss: 0.4813 - val_accuracy: 0.8395
# Epoch 16/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.2881 - accuracy: 0.8893 - val_loss: 0.4768 - val_accuracy: 0.8355
# Epoch 17/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.2787 - accuracy: 0.8947 - val_loss: 0.4570 - val_accuracy: 0.8515
# Epoch 18/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.2480 - accuracy: 0.9106 - val_loss: 0.5614 - val_accuracy: 0.8210
# Epoch 19/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.2399 - accuracy: 0.9121 - val_loss: 0.4208 - val_accuracy: 0.8629
# Epoch 20/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.2209 - accuracy: 0.9184 - val_loss: 0.5131 - val_accuracy: 0.8298
# Epoch 21/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.2119 - accuracy: 0.9200 - val_loss: 0.5157 - val_accuracy: 0.8372
# Epoch 22/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.1931 - accuracy: 0.9274 - val_loss: 0.4953 - val_accuracy: 0.8438
# Epoch 23/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.1886 - accuracy: 0.9271 - val_loss: 0.5364 - val_accuracy: 0.8409
# Epoch 24/25
# 329/329 [==============================] - 167s 509ms/step - loss: 0.1808 - accuracy: 0.9315 - val_loss: 0.5375 - val_accuracy: 0.8361
# Epoch 25/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.1555 - accuracy: 0.9418 - val_loss: 0.4966 - val_accuracy: 0.8475
# CPU times: user 15min 36s, sys: 2min 58s, total: 18min 35s
# Wall time: 1h 10min 9s
# 94/94 [==============================] - 37s 389ms/step - loss: 0.5471 - accuracy: 0.8377
# Test image accuracy :0.8376666903495789
# Classification Report
#               precision    recall  f1-score   support
#
#    buildings       0.86      0.82      0.84       437
#       forest       0.94      0.97      0.96       474
#      glacier       0.79      0.77      0.78       553
#     mountain       0.83      0.68      0.75       525
#          sea       0.74      0.93      0.82       510
#       street       0.90      0.87      0.88       501
#
#     accuracy                           0.84      3000
#    macro avg       0.84      0.84      0.84      3000
# weighted avg       0.84      0.84      0.84      3000
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       1180160
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               589952
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 4,540,486
# Trainable params: 4,539,462
# Non-trainable params: 1,024
# _________________________________________________________________
# None

# %% [markdown]
# Accuracy has inched a further from 0.83 to 0.84 with an addition of CNN + Max Pooling.

# %%
# Change learning rate to 0.0001

## 6 layer cnn + max pooling + batchnormalization
model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D( activation='relu', input_shape=(224, 224, 3),padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation=tf.nn.relu),
tf.keras.layers.Dense(6, activation=tf.nn.softmax)])

optim = tf.keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(optimizer= optim, loss='sparse_categorical_crossentropy', metrics=['accuracy'], )
# %time history = model.fit(train_ds, epochs=25, validation_data = val_ds)
##
test_loss, test_acc = model.evaluate(test_ds)
print("Test image accuracy :{}".format(test_acc))
##
plt.plot(history.history['accuracy'], '-o' ,label='accuracy')
plt.plot(history.history['val_accuracy'], '-o', label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
##
model.save('model_cnn6')
##

## for validation data set , check the classification report.
val_pred = np.array([])
val_labels = np.array([])
for x, y in test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    val_pred = np.concatenate([val_pred,np.array(predictions)])
    val_labels = np.concatenate([val_labels , y.numpy()])
    
##
print('Classification Report')
target_names = class_names
print(classification_report(val_labels, val_pred, target_names=class_names))
##
print(model.summary())
##
pred_images_prediction = model.predict(pred_images)
##
pred_images_class = []
for i in range(len(pred_images_prediction)):
    pred_images_class.append(np.argmax(pred_images_prediction[i], axis = -1))
##
## visualize prediction images with the prediction 
plt.figure(figsize=(10, 10))
for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(pred_images[i])
    plt.title(class_names[pred_images_class[i]])
    plt.axis("off")
# Out:
# Epoch 1/25
# 329/329 [==============================] - 169s 511ms/step - loss: 1.5367 - accuracy: 0.4010 - val_loss: 1.7865 - val_accuracy: 0.1773
# Epoch 2/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.9146 - accuracy: 0.6487 - val_loss: 1.4291 - val_accuracy: 0.4532
# Epoch 3/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.7379 - accuracy: 0.7203 - val_loss: 1.3087 - val_accuracy: 0.5353
# Epoch 4/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.6187 - accuracy: 0.7753 - val_loss: 1.2213 - val_accuracy: 0.5835
# Epoch 5/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.5587 - accuracy: 0.7973 - val_loss: 0.9365 - val_accuracy: 0.6517
# Epoch 6/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.5067 - accuracy: 0.8131 - val_loss: 0.8530 - val_accuracy: 0.6887
# Epoch 7/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.4568 - accuracy: 0.8338 - val_loss: 1.0081 - val_accuracy: 0.6631
# Epoch 8/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.4282 - accuracy: 0.8457 - val_loss: 0.8709 - val_accuracy: 0.7044
# Epoch 9/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.3847 - accuracy: 0.8657 - val_loss: 0.9304 - val_accuracy: 0.7118
# Epoch 10/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.3595 - accuracy: 0.8668 - val_loss: 0.6812 - val_accuracy: 0.7662
# Epoch 11/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.3267 - accuracy: 0.8809 - val_loss: 0.6053 - val_accuracy: 0.7942
# Epoch 12/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.3124 - accuracy: 0.8851 - val_loss: 0.6370 - val_accuracy: 0.7970
# Epoch 13/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.2829 - accuracy: 0.8911 - val_loss: 1.0767 - val_accuracy: 0.6924
# Epoch 14/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.2758 - accuracy: 0.8974 - val_loss: 0.8954 - val_accuracy: 0.7326
# Epoch 15/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.2370 - accuracy: 0.9140 - val_loss: 0.5924 - val_accuracy: 0.8144
# Epoch 16/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.2203 - accuracy: 0.9185 - val_loss: 0.6023 - val_accuracy: 0.8258
# Epoch 17/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.1840 - accuracy: 0.9317 - val_loss: 0.8050 - val_accuracy: 0.7594
# Epoch 18/25
# 329/329 [==============================] - 168s 511ms/step - loss: 0.1586 - accuracy: 0.9437 - val_loss: 0.7540 - val_accuracy: 0.7996
# Epoch 19/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.1634 - accuracy: 0.9424 - val_loss: 0.6342 - val_accuracy: 0.8235
# Epoch 20/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.1316 - accuracy: 0.9527 - val_loss: 0.4989 - val_accuracy: 0.8538
# Epoch 21/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.1187 - accuracy: 0.9571 - val_loss: 0.6502 - val_accuracy: 0.8261
# Epoch 22/25
# 329/329 [==============================] - 168s 509ms/step - loss: 0.1006 - accuracy: 0.9678 - val_loss: 0.6147 - val_accuracy: 0.8290
# Epoch 23/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.0882 - accuracy: 0.9682 - val_loss: 0.5705 - val_accuracy: 0.8501
# Epoch 24/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.0834 - accuracy: 0.9716 - val_loss: 0.5871 - val_accuracy: 0.8461
# Epoch 25/25
# 329/329 [==============================] - 168s 510ms/step - loss: 0.0809 - accuracy: 0.9727 - val_loss: 0.6649 - val_accuracy: 0.8387
# CPU times: user 15min 40s, sys: 2min 59s, total: 18min 40s
# Wall time: 1h 10min 1s
# 94/94 [==============================] - 33s 352ms/step - loss: 0.6588 - accuracy: 0.8343
# Test image accuracy :0.8343333601951599
# Classification Report
#               precision    recall  f1-score   support
#
#    buildings       0.84      0.84      0.84       437
#       forest       0.91      0.98      0.95       474
#      glacier       0.88      0.64      0.74       553
#     mountain       0.77      0.85      0.81       525
#          sea       0.75      0.91      0.82       510
#       street       0.90      0.81      0.86       501
#
#     accuracy                           0.83      3000
#    macro avg       0.84      0.84      0.83      3000
# weighted avg       0.84      0.83      0.83      3000
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 14, 14, 256)       0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 512)       1180160
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               589952
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 4,540,486
# Trainable params: 4,539,462
# Non-trainable params: 1,024
# _________________________________________________________________
# None

# %% [markdown]
# Accuracy reduced to 0.83 from 0.84 with the change in learning rate.

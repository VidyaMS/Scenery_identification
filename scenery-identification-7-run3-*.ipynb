# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn.metrics import classification_report

# %%
image_path = "../input/intel-image-classification/seg_train/seg_train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="training",
  seed=333)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  image_path,
  image_size=(224,224),
  batch_size=32,
validation_split=0.25,
  subset="validation",
  seed=333)

test_path = "../input/intel-image-classification/seg_test/seg_test"
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
  image_size=(224,224),
  batch_size=32)

new_test_path = "../input/new-test-dataset/test_images"
new_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  new_test_path,
  image_size=(224,224),
  batch_size=32)
# Out:
# Found 14034 files belonging to 6 classes.
# Using 10526 files for training.
# Found 14034 files belonging to 6 classes.
# Using 3508 files for validation.
# Found 3000 files belonging to 6 classes.
# Found 37 files belonging to 6 classes.

# %%
import glob
import pathlib 

data_dir = pathlib.Path(image_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %%
## visualize train set images
image_batch, label_batch = next(iter(train_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize validation images 
image_batch, label_batch = next(iter(val_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize test images 
image_batch, label_batch = next(iter(test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
## visualize new test images 
image_batch, label_batch = next(iter(new_test_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    name = class_names[label]
    plt.title(name)
    plt.axis("off")

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.resize(img , (224,224))
        if img is not None:
            images.append(img)
    return images

pred_images = load_images_from_folder("../input/intel-image-classification/seg_pred/seg_pred")

# %%
type(pred_images)
# Out:
# list

# %%
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 224, 224, 3)

# %%
## visualize prediction images 
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(pred_images[i])
    plt.axis("off")

# %%
## 7 layer cnn + max pooling + batchnormalization

model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D( activation='relu', input_shape=(224, 224, 3),padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 64, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 128, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 256, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Conv2D( activation='relu', padding = 'same', filters = 512, kernel_size = 3),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2, 2)), 
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.BatchNormalization(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation=tf.nn.relu),
tf.keras.layers.Dense(6, activation=tf.nn.softmax)])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'], )
# %time history = model.fit(train_ds, epochs=25, validation_data = val_ds)
##
test_loss, test_acc = model.evaluate(test_ds)
print("Test image accuracy :{}".format(test_acc))
##
test_loss_new, test_acc_new = model.evaluate(new_test_ds)
print("Test image accuracy for new data set :{}".format(test_acc_new))
##
plt.plot(history.history['accuracy'], '-o' ,label='accuracy')
plt.plot(history.history['val_accuracy'], '-o', label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
##
model.save('model_cnn_7')
##

## for test data set , check the classification report.
val_pred = np.array([])
val_labels = np.array([])
for x, y in test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    val_pred = np.concatenate([val_pred,np.array(predictions)])
    val_labels = np.concatenate([val_labels , y.numpy()])
    
##
print('Classification Report for test ds')
target_names = class_names
print(classification_report(val_labels, val_pred, target_names=class_names))
##
## for new test data set , check the classification report.
new_val_pred = np.array([])
new_val_labels = np.array([])
for x, y in new_test_ds:
    predictions =  np.argmax(model.predict(x), axis = -1)
    new_val_pred = np.concatenate([new_val_pred,np.array(predictions)])
    new_val_labels = np.concatenate([new_val_labels , y.numpy()])
    
##
print('Classification Report for new test ds')
target_names = class_names
print(classification_report(new_val_labels, new_val_pred, target_names=class_names))
##
print(model.summary())
##
pred_images_prediction = model.predict(pred_images)
##
pred_images_class = []
for i in range(len(pred_images_prediction)):
    pred_images_class.append(np.argmax(pred_images_prediction[i], axis = -1))
##
## visualize prediction images with the prediction 
plt.figure(figsize=(10, 10))
for i in range(20):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(pred_images[i])
    plt.title(class_names[pred_images_class[i]])
    plt.axis("off")
# Out:
# Epoch 1/25
# 329/329 [==============================] - 244s 720ms/step - loss: 1.4127 - accuracy: 0.4542 - val_loss: 1.2354 - val_accuracy: 0.5182
# Epoch 2/25
# 329/329 [==============================] - 171s 519ms/step - loss: 1.0413 - accuracy: 0.5850 - val_loss: 1.0436 - val_accuracy: 0.5818
# Epoch 3/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.8446 - accuracy: 0.6613 - val_loss: 1.8326 - val_accuracy: 0.3435
# Epoch 4/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.7485 - accuracy: 0.7078 - val_loss: 1.0752 - val_accuracy: 0.5864
# Epoch 5/25
# 329/329 [==============================] - 171s 518ms/step - loss: 0.7909 - accuracy: 0.6902 - val_loss: 0.7085 - val_accuracy: 0.7420
# Epoch 6/25
# 329/329 [==============================] - 171s 518ms/step - loss: 0.6348 - accuracy: 0.7601 - val_loss: 0.9774 - val_accuracy: 0.6417
# Epoch 7/25
# 329/329 [==============================] - 171s 518ms/step - loss: 0.5675 - accuracy: 0.7887 - val_loss: 0.7955 - val_accuracy: 0.7189
# Epoch 8/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.5105 - accuracy: 0.8118 - val_loss: 0.5466 - val_accuracy: 0.8184
# Epoch 9/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.4726 - accuracy: 0.8267 - val_loss: 0.5673 - val_accuracy: 0.8002
# Epoch 10/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.4448 - accuracy: 0.8382 - val_loss: 3.4977 - val_accuracy: 0.5331
# Epoch 11/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.4292 - accuracy: 0.8444 - val_loss: 0.4641 - val_accuracy: 0.8389
# Epoch 12/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.3900 - accuracy: 0.8571 - val_loss: 0.6306 - val_accuracy: 0.7677
# Epoch 13/25
# 329/329 [==============================] - 172s 521ms/step - loss: 0.3803 - accuracy: 0.8576 - val_loss: 0.5459 - val_accuracy: 0.7979
# Epoch 14/25
# 329/329 [==============================] - 170s 518ms/step - loss: 0.3498 - accuracy: 0.8760 - val_loss: 0.7187 - val_accuracy: 0.7403
# Epoch 15/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.3885 - accuracy: 0.8580 - val_loss: 0.5187 - val_accuracy: 0.8025
# Epoch 16/25
# 329/329 [==============================] - 171s 519ms/step - loss: 0.3215 - accuracy: 0.8769 - val_loss: 0.4007 - val_accuracy: 0.8629
# Epoch 17/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.3945 - accuracy: 0.8554 - val_loss: 0.9670 - val_accuracy: 0.6887
# Epoch 18/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.4987 - accuracy: 0.8151 - val_loss: 0.7471 - val_accuracy: 0.7320
# Epoch 19/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.3793 - accuracy: 0.8611 - val_loss: 0.4804 - val_accuracy: 0.8384
# Epoch 20/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.3477 - accuracy: 0.8762 - val_loss: 0.4356 - val_accuracy: 0.8523
# Epoch 21/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.2746 - accuracy: 0.8973 - val_loss: 0.4602 - val_accuracy: 0.8546
# Epoch 22/25
# 329/329 [==============================] - 171s 520ms/step - loss: 0.2389 - accuracy: 0.9106 - val_loss: 0.5116 - val_accuracy: 0.8643
# Epoch 23/25
# 329/329 [==============================] - 171s 521ms/step - loss: 0.2243 - accuracy: 0.9176 - val_loss: 0.5035 - val_accuracy: 0.8558
# Epoch 24/25
# 329/329 [==============================] - 171s 521ms/step - loss: 0.2297 - accuracy: 0.9130 - val_loss: 0.7323 - val_accuracy: 0.8025
# Epoch 25/25
# 329/329 [==============================] - 171s 521ms/step - loss: 0.1952 - accuracy: 0.9292 - val_loss: 0.8141 - val_accuracy: 0.7865
# CPU times: user 15min 34s, sys: 3min 12s, total: 18min 46s
# Wall time: 1h 12min 29s
# 94/94 [==============================] - 49s 515ms/step - loss: 0.7785 - accuracy: 0.7897
# Test image accuracy :0.7896666526794434
# 2/2 [==============================] - 1s 457ms/step - loss: 2.4114 - accuracy: 0.4865
# Test image accuracy for new data set :0.4864864945411682
# Classification Report for test ds
#               precision    recall  f1-score   support
#
#    buildings       0.88      0.63      0.74       437
#       forest       0.78      0.97      0.87       474
#      glacier       0.83      0.74      0.78       553
#     mountain       0.76      0.83      0.80       525
#          sea       0.67      0.94      0.79       510
#       street       0.93      0.59      0.73       501
#
#     accuracy                           0.79      3000
#    macro avg       0.81      0.79      0.78      3000
# weighted avg       0.81      0.79      0.78      3000
#
# Classification Report for new test ds
#               precision    recall  f1-score   support
#
#    buildings       1.00      0.67      0.80         6
#       forest       0.50      0.80      0.62         5
#      glacier       0.86      1.00      0.92         6
#     mountain       0.71      0.83      0.77         6
#          sea       0.88      1.00      0.93         7
#       street       1.00      0.43      0.60         7
#
#     accuracy                           0.78        37
#    macro avg       0.82      0.79      0.77        37
# weighted avg       0.84      0.78      0.78        37
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 512)       1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 6,376,006
# Trainable params: 6,374,982
# Non-trainable params: 1,024
# _________________________________________________________________
# None
